# %%
import numpy as np
import pandas as pd

# %%
righe=list('ABCDE')
colonne=list('FGHIL')

# %%
df=pd.DataFrame(np.random.randint(10,size=(5,5)),index=righe,columns=colonne)

# %%
df
# Out:
#    F  G  H  I  L
# A  7  0  3  5  9
# B  6  9  9  7  0
# C  9  7  0  4  2
# D  3  6  0  9  3
# E  0  1  6  1  6

# %%
nuovo_indice=[1,2,3,4,5]

# %%
nuovo_indice
# Out:
# [1, 2, 3, 4, 5]

# %%
df['nuovo_indice']=nuovo_indice

# %%
df
# Out:
#    F  G  H  I  L  nuovo_indice
# A  7  0  3  5  9             1
# B  6  9  9  7  0             2
# C  9  7  0  4  2             3
# D  3  6  0  9  3             4
# E  0  1  6  1  6             5

# %%
df.reset_index()
# Out:
#   index  F  G  H  I  L  nuovo_indice
# 0     A  7  0  3  5  9             1
# 1     B  6  9  9  7  0             2
# 2     C  9  7  0  4  2             3
# 3     D  3  6  0  9  3             4
# 4     E  0  1  6  1  6             5

# %%
df.set_index('nuovo_indice')
# Out:
#               F  G  H  I  L
# nuovo_indice
# 1             7  0  3  5  9
# 2             6  9  9  7  0
# 3             9  7  0  4  2
# 4             3  6  0  9  3
# 5             0  1  6  1  6

# %%
df
# Out:
#    F  G  H  I  L  nuovo_indice
# A  7  0  3  5  9             1
# B  6  9  9  7  0             2
# C  9  7  0  4  2             3
# D  3  6  0  9  3             4
# E  0  1  6  1  6             5

# %%
df.set_index('nuovo_indice',inplace=True)

# %%
df
# Out:
#               F  G  H  I  L
# nuovo_indice
# 1             7  0  3  5  9
# 2             6  9  9  7  0
# 3             9  7  0  4  2
# 4             3  6  0  9  3
# 5             0  1  6  1  6

# %%
df.reset_index(drop=True)
# Out:
#    F  G  H  I  L
# 0  7  0  3  5  9
# 1  6  9  9  7  0
# 2  9  7  0  4  2
# 3  3  6  0  9  3
# 4  0  1  6  1  6

# %%
df.set_index(['F','G'],inplace=True)

# %%
df
# Out:
#      H  I  L
# F G
# 4 2  1  4  2
# 1 1  4  7  6
# 8 8  1  6  0
# 2 3  3  2  6
# 5 5  1  6  3

# %%
df.sort_index()
# Out:
#      H  I  L
# F G
# 1 1  4  7  6
# 2 3  3  2  6
# 4 2  1  4  2
# 5 5  1  6  3
# 8 8  1  6  0
