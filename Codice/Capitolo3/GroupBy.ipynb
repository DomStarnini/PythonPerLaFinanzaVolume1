# %%
import pandas as pd

# %%
data={'SYMBOL':['AAPL','AAPL','MSFT','MSFT','NFLX','NFLX'],
     'PERSONA':['ALDO','GIUSEPPE','FILIPPO','CRISTINA','ROBERTO','GIADA'],
     'QUANTITA':[150,200,450,100,320,490]}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#   SYMBOL   PERSONA  QUANTITA
# 0   AAPL      ALDO       150
# 1   AAPL  GIUSEPPE       200
# 2   MSFT   FILIPPO       450
# 3   MSFT  CRISTINA       100
# 4   NFLX   ROBERTO       320
# 5   NFLX     GIADA       490

# %%
df.groupby('SYMBOL').mean()
# Out:
#         QUANTITA
# SYMBOL
# AAPL         175
# MSFT         275
# NFLX         405

# %%
df.groupby('SYMBOL').max()
# Out:
#          PERSONA  QUANTITA
# SYMBOL
# AAPL    GIUSEPPE       200
# MSFT     FILIPPO       450
# NFLX     ROBERTO       490

# %%
df.groupby('SYMBOL').min()
# Out:
#          PERSONA  QUANTITA
# SYMBOL
# AAPL        ALDO       150
# MSFT    CRISTINA       100
# NFLX       GIADA       320

# %%
df.groupby('SYMBOL').std()
# Out:
#           QUANTITA
# SYMBOL
# AAPL     35.355339
# MSFT    247.487373
# NFLX    120.208153

# %%
df.groupby('SYMBOL').sum()
# Out:
#         QUANTITA
# SYMBOL
# AAPL         350
# MSFT         550
# NFLX         810

# %%
df.groupby('SYMBOL').describe()
# Out:
#        QUANTITA
#           count   mean         std    min    25%    50%    75%    max
# SYMBOL
# AAPL        2.0  175.0   35.355339  150.0  162.5  175.0  187.5  200.0
# MSFT        2.0  275.0  247.487373  100.0  187.5  275.0  362.5  450.0
# NFLX        2.0  405.0  120.208153  320.0  362.5  405.0  447.5  490.0

# %%
df.groupby('SYMBOL').describe().transpose()
# Out:
# SYMBOL                AAPL        MSFT        NFLX
# QUANTITA count    2.000000    2.000000    2.000000
#          mean   175.000000  275.000000  405.000000
#          std     35.355339  247.487373  120.208153
#          min    150.000000  100.000000  320.000000
#          25%    162.500000  187.500000  362.500000
#          50%    175.000000  275.000000  405.000000
#          75%    187.500000  362.500000  447.500000
#          max    200.000000  450.000000  490.000000
